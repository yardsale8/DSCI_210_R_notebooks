# %% [markdown]
# <a href="https://colab.research.google.com/github/yardsale8/DSCI_210_R_notebooks/blob/main/lecture_7_1_1_loading_data_in_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started with `dplyr`
#
# In this notebook, we will look at the basics of data management in R, including
#
# 1. Loading a CSV file using `read.csv`,
# 2. Inspecting the data using `head`,
# 3. Applying `select`, `filter`, and `mutate`, and
# 4. Performing a data management process using a pipe.

# %% [markdown]
# ### Why use R?
#
#
# - Save and rerun code
# - Lots of stats/data science packages
# - Great graphics
# - Built for data
# - free, open source, cross-platform
# - Large community

# %% [markdown]
# ### Market-share
#
# ![](https://github.com/WSU-DataScience/DSCI_210_R_notebooks/blob/main/img/Fig-1a-IndeedJobs-2017.png?raw=1)

# %% [markdown]
# What is the `tidyverse`?
# ========================================================
#
# - Multiple packages for managing and manipulating data, using data verb syntax
#     - `dplyr`
#         - filter
#         - mutate
#         - aggregate
#     - `tidyr`
#         - stack and unstack (`gather()` and `spread()`)
#     - `ggplot`
#         - Nice graphics

# %% [markdown]
# ### Loading a Library

# %%
# This loads all of the dplyr functions
#must do everytime you start new R session
library("tidyverse")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# #### Reading in data

# %% [markdown]
# #### Method 1 - Using a web link
#
# Use the `read.csv` function with a web link in quotes.

# %%
surveys <- read.csv('https://github.com/WSU-DataScience/DSCI_210_R_notebooks/raw/main/data/portal_data_joined.csv')
head(surveys)
# Out:
#   record_id month day year plot_id species_id sex hindfoot_length weight
# 1   1        7    16  1977 2       NL         M   32              NA
# 2  72        8    19  1977 2       NL         M   31              NA
# 3 224        9    13  1977 2       NL             NA              NA
# 4 266       10    16  1977 2       NL             NA              NA
# 5 349       11    12  1977 2       NL             NA              NA
# 6 363       11    12  1977 2       NL             NA              NA
#   genus   species  taxa   plot_type
# 1 Neotoma albigula Rodent Control
# 2 Neotoma albigula Rodent Control
# 3 Neotoma albigula Rodent Control
# 4 Neotoma albigula Rodent Control
# 5 Neotoma albigula Rodent Control
# 6 Neotoma albigula Rodent Control

# %% [markdown]
# #### How to get a link from GitHub
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="red"> Exercise 7.1.1 </font>
#
# 1. Go to https://github.com/yardsale8/DSCI_210_R_notebooks,
# 2. Navigate to the `data\Football_Sleep_data.csv`,
# 3. Copy the raw link, and
# 4. Use `read.csv` to save the table in a variable named `football`.
# 5. Inspect the table by evaluating the variable (put `football` on the last line).

# %%
# Your code here

# %% [markdown]
# #### Method 2 - Uploading a CSV to Colab
#
# ![image.png](data:image/png;base64,...)
#
# To load data from a CSV in Colab, you need to upload to the `Content` Folder

# %%
mosquito_patch <- read.csv("mosquito_patch.csv")

mosquito_patch %>% head
# Out:
#   Treatment Mosquitoes.Per.Hour
# 1 Odomos     4.50
# 2 Odomos    10.04
# 3 Odomos    13.05
# 4 Odomos     0.26
# 5 Odomos    10.61
# 6 Odomos    10.89

# %% [markdown]
# ## <font color="red"> Exercise 7.1.2 </font>
#
# 1. Upload  `NC_births.csv` to the Colab content folder.
# 2. Load the data using the file inside `read.csv` in the first code cell.  Save the table to a variable named `births`
# 3. Inspect the data using `head`

# %%
# Your code here

# %% [markdown]
# ## Deliverables
#
# Please submit the following on D2L.
#
# 1. A WORD document containing screenshots of your solutions (code + output), and
# 2. A share link to your notebook.  You will need to save a copy of your notebook and change the share permissions to allow anyone with the link access.  **Make sure you save a open to Drive, then change the permissions!**
